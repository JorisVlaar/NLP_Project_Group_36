# %%
import pandas as pd
import numpy as np
import pandas as pd
import fasttext
from ast import literal_eval
from collections import Counter

# %%
# Load the data into pandas DataFrames
print("Loading datasets...")
reviews_df = pd.read_csv("./archive/dataset.csv")  # columns: app_id, app_name, review_text
# Out:
# Loading datasets...

# %%
tags_df = pd.read_csv("output.csv")        # columns: APPID, tags

# Map the string representation of lists/dicts back to actual lists/dicts using literal_eval
tags_df['tags'] = [literal_eval(x) for x in tags_df['tags']]

# # Enable this line if you want to ignore the count of tags
new_tags = []
for x in tags_df['tags']:    
    if isinstance(x, dict):
        keys_list = list(x.keys())  
        new_tags.append(keys_list) 
    else:
        # If no tags
        new_tags.append([])
tags_df['tags'] = new_tags

print(tags_df.head())
# Out:
#     APPID                                               tags
# 0      10  [Action, FPS, Multiplayer, Shooter, Classic, T...
# 1    1002  [2D Fighter, Martial Arts, Intentionally Awkwa...
# 2  100400                   [Animation & Modeling, Software]
# 3   10090  [Zombies, World War II, FPS, Multiplayer, Acti...
# 4  100980  [Animation & Modeling, Utilities, Design & Ill...

# %%
def filter_rare_tags(tags_df, min_count=5):
    """
    Filters out tags that occur less than min_count times across all games.
    
    Args:
        tags_df (pd.DataFrame): columns ['APPID', 'tags'], where 'tags' is a list of tag names
        min_count (int): minimum number of occurrences required to keep a tag
    
    Returns:
        pd.DataFrame: filtered tags_df
    """
    # Flatten all tags into a single list
    all_tags = [tag for tags in tags_df['tags'] for tag in tags]
    tag_counts = Counter(all_tags)
    print(len(tag_counts), tag_counts)
    # Keep only tags above threshold
    allowed_tags = {tag for tag, count in tag_counts.items() if count >= min_count}
    # print(len(allowed_tags), allowed_tags)
    # Filter tags per game
    def keep_tags(tag_list):
        return [tag for tag in tag_list if tag in allowed_tags]
    
    tags_df['tags'] = tags_df['tags'].apply(keep_tags)
    
    # Optionally, drop games with no tags left after filtering
    tags_df = tags_df[tags_df['tags'].str.len() > 0].reset_index(drop=True)
    
    return tags_df

# Apply rare tag filtering
tags_df = filter_rare_tags(tags_df, min_count=500)
# print("Tags after rare tag filtering:", tags_df.shape)
print(tags_df)
# Out:
# 446 Counter({'Indie': 6304, 'Action': 5048, 'Singleplayer': 4482, 'Adventure': 4335, 'Casual': 3422, 'Strategy': 2523, 'Multiplayer': 2068, 'Simulation': 2068, 'RPG': 1991, '2D': 1990, 'Atmospheric': 1737, 'Puzzle': 1722, 'Great Soundtrack': 1630, 'Story Rich': 1327, 'Shooter': 1198, 'Sci-fi': 1196, 'First-Person': 1134, 'Platformer': 1117, 'Funny': 1100, 'Fantasy': 1089, 'Difficult': 1086, 'Open World': 1061, 'Co-op': 1060, 'Pixel Graphics': 1049, 'Horror': 1044, 'Female Protagonist': 1041, 'Arcade': 953, 'Retro': 950, 'Free to Play': 887, 'Point & Click': 824, 'Anime': 813, 'Classic': 802, 'FPS': 776, 'Early Access': 774, 'Exploration': 757, 'Comedy': 755, 'Survival': 723, 'Family Friendly': 722, 'Sandbox': 712, 'Third Person': 690, 'Cute': 646, 'Turn-Based': 627, 'Space': 626, 'VR': 605, 'Gore': 579, 'Controller': 538, 'Tactical': 495, 'Local Co-Op': 484, 'Local Multiplayer': 483, 'Colorful': 480, 'Psychological Horror': 466, 'Sports': 453, 'Visual Novel': 440, 'Side Scroller': 435, 'Online Co-Op': 429, "Shoot 'Em Up": 424, 'Racing': 420, 'Massively Multiplayer': 413, 'RTS': 407, 'Zombies': 404, 'Mystery': 401, 'Turn-Based Strategy': 399, 'Top-Down': 397, 'Violent': 374, 'Management': 374, 'Short': 372, 'Building': 372, 'Historical': 367, 'Nudity': 364, 'Rogue-like': 361, 'Physics': 358, 'Dark': 358, 'Replay Value': 343, 'Action RPG': 343, 'Puzzle-Platformer': 332, 'War': 327, '3D': 327, 'PvP': 321, 'Choices Matter': 312, 'Hidden Object': 308, 'Hack and Slash': 303, 'Memes': 303, 'Isometric': 299, 'Relaxing': 293, 'Crafting': 291, 'Survival Horror': 285, 'Realistic': 283, 'Bullet Hell': 281, 'Stealth': 274, 'Fast-Paced': 274, 'Procedural Generation': 273, 'Character Customization': 264, 'Walking Simulator': 262, "1990's": 258, 'Old School': 256, 'Tower Defense': 254, 'Action-Adventure': 253, 'Third-Person Shooter': 253, 'Moddable': 249, 'Military': 243, 'Post-apocalyptic': 242, 'Rogue-lite': 240, 'JRPG': 233, 'Cartoony': 228, 'Medieval': 228, 'Sexual Content': 224, '4 Player Local': 224, 'Dungeon Crawler': 222, 'RPGMaker': 220, 'Competitive': 214, 'Mature': 214, 'Magic': 213, 'Turn-Based Combat': 210, 'Futuristic': 208, 'Multiple Endings': 205, 'Robots': 201, 'Surreal': 200, 'Minimalist': 199, 'Turn-Based Tactics': 197, 'Dark Fantasy': 192, 'Education': 190, 'Stylized': 190, 'Choose Your Own Adventure': 189, 'Romance': 189, 'Cyberpunk': 188, 'Aliens': 187, 'Driving': 185, 'Board Game': 184, 'Detective': 183, 'World War II': 179, 'Top-Down Shooter': 178, 'Flight': 178, 'Fighting': 177, 'Base-Building': 177, "Beat 'em up": 176, 'Hand-drawn': 173, '2.5D': 172, 'Cult Classic': 171, 'Dating Sim': 171, 'Resource Management': 166, 'Economy': 164, 'Music': 163, 'Card Game': 161, 'Twin Stick Shooter': 161, 'Metroidvania': 160, 'Action Roguelike': 159, 'Automobile Sim': 158, 'City Builder': 154, '3D Platformer': 154, 'Grand Strategy': 149, 'Level Editor': 149, '2D Platformer': 149, 'Interactive Fiction': 148, 'Remake': 143, 'Dark Humor': 142, 'Perma Death': 139, 'MMORPG': 138, 'Steampunk': 137, 'Linear': 135, 'Wargame': 129, 'PvE': 124, 'Cartoon': 123, 'Abstract': 123, 'Utilities': 121, 'Party-Based RPG': 121, 'Team-Based': 120, 'Space Sim': 120, 'Parkour': 118, 'Real Time Tactics': 115, 'Match 3': 115, 'Loot': 114, 'Combat': 112, 'Arena Shooter': 111, 'Addictive': 110, 'Real-Time with Pause': 109, 'Touch-Friendly': 109, '4X': 109, 'LGBTQ+': 107, 'Split Screen': 104, 'Destruction': 104, 'Crime': 103, 'Time Management': 103, 'Experimental': 101, 'Score Attack': 100, 'CRPG': 100, 'Real-Time': 99, 'Psychedelic': 99, 'Illuminati': 99, 'Rhythm': 98, 'Design & Illustration': 97, 'Logic': 97, 'Beautiful': 96, 'Dystopian ': 93, 'Mechs': 92, 'Tactical RPG': 92, 'Text-Based': 92, '1980s': 91, 'Kickstarter': 91, 'Mouse only': 90, 'Open World Survival Craft': 89, 'Pirates': 89, 'Software': 86, 'Lovecraftian': 85, 'Immersive Sim': 85, 'Noir': 84, 'Strategy RPG': 84, 'Drama': 84, 'Hentai': 83, '2D Fighter': 81, 'Blood': 81, 'Narration': 80, 'Psych ...
#       APPID                                               tags
# 0        10  [Action, FPS, Multiplayer, Shooter, Classic, F...
# 1      1002     [Indie, Multiplayer, Singleplayer, Action, 2D]
# 2     10090  [FPS, Multiplayer, Action, Shooter, Singleplay...
# 3     10100  [Adventure, Point & Click, Classic, Fantasy, R...
# 4     10110  [Adventure, Point & Click, Classic, Comedy, Re...
# ...     ...                                                ...
# 9829  99810  [FPS, Action, Comedy, Gore, Shooter, Singlepla...
# 9830  99830  [Action, FPS, Sci-fi, Shooter, Singleplayer, M...
# 9831   9990                                [Adventure, Action]
# 9832  99900  [Free to Play, RPG, Adventure, Action, Multipl...
# 9833  99910  [Free to Play, Puzzle, Casual, Strategy, Adven...
#
# [9834 rows x 2 columns]

# %%
# -----------------------------
# 2. Aggregate reviews per game (only games with tags available)
# -----------------------------

print("Aggregating reviews per game...")

reviews_df['app_id'] = reviews_df['app_id'].astype(int)
tags_df['APPID'] = tags_df['APPID'].astype(int)

# Filter reviews to only include games present in tags_df
reviews_with_tags = reviews_df[reviews_df['app_id'].isin(tags_df['APPID'])]
print(reviews_with_tags.head(5))

# Convert review_text to string
reviews_with_tags['review_text'] = reviews_with_tags['review_text'].astype(str)

# Filter out reviews shorter than 3 words
reviews_with_tags = reviews_with_tags.loc[reviews_with_tags['review_text'].str.split().str.len() >= 3]

print("Filtered reviews shape:", reviews_with_tags.shape)

# Aggregate reviews per game and keep app_name
game_reviews = (
    reviews_with_tags.groupby('app_id')
    .agg({
        'review_text': lambda texts: " ".join(texts),
        'app_name': 'first'  # keep the first app_name per app_id
    })
    .reset_index()
)
print("Aggregated reviews shape:", game_reviews.shape)

# Merge with filtered tags
game_reviews = game_reviews.merge(tags_df, left_on='app_id', right_on='APPID')
print("Merged game_reviews shape:", game_reviews.shape)

print("Sample data:")
print(game_reviews.head())
# Out:
# Aggregating reviews per game...
#    app_id        app_name                                        review_text  \
# 0      10  Counter-Strike                                    Ruined my life.
# 1      10  Counter-Strike  This will be more of a ''my experience with th...
# 2      10  Counter-Strike                      This game saved my virginity.
# 3      10  Counter-Strike  • Do you like original games? • Do you like ga...
# 4      10  Counter-Strike           Easy to learn, hard to master.
#
#    review_score  review_votes
# 0             1             0
# 1             1             1
# 2             1             0
# 3             1             0
# 4             1             1
# C:\Users\youdy\AppData\Local\Temp\ipykernel_13196\3972742872.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_with_tags['review_text'] = reviews_with_tags['review_text'].astype(str)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 18
#      15 reviews_with_tags['review_text'] = reviews_with_tags['review_text'].astype(str)
#      17 # Filter out reviews shorter than 3 words
# ---> 18 reviews_with_tags = reviews_with_tags.loc[reviews_with_tags['review_text'].str.split().str.len() >= 3]
#      20 print("Filtered reviews shape:", reviews_with_tags.shape)
#      22 # Aggregate reviews per game and keep app_name
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\strings\accessor.py:140, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     135     msg = (
#     136         f"Cannot use .str.{func_name} with values of "
#     137         f"inferred dtype '{self._inferred_dtype}'."
#     138     )
#     139     raise TypeError(msg)
# --> 140 return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\strings\accessor.py:924, in StringMethods.split(self, pat, n, expand, regex)
#     922 if is_re(pat):
#     923     regex = True
# --> 924 result = self._data.array._str_split(pat, n, expand, regex)
#     925 if self._data.dtype == "category":
#     926     dtype = self._data.dtype.categories.dtype
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\strings\object_array.py:398, in ObjectStringArrayMixin._str_split(self, pat, n, expand, regex)
#     396             n = -1
#     397         f = lambda x: x.split(pat, n)
# --> 398 return self._str_map(f, dtype=object)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\strings\object_array.py:82, in ObjectStringArrayMixin._str_map(self, f, na_value, dtype, convert)
#      80 map_convert = convert and not np.all(mask)
#      81 try:
# ---> 82     result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      83 except (TypeError, AttributeError) as err:
#      84     # Reraise the exception if callable `f` got wrong number of args.
#      85     # The user may want to be warned by this, instead of getting NaN
#      86     p_err = (
#      87         r"((takes)|(missing)) (?(2)from \d+ to )?\d+ "
#      88         r"(?(3)required )positional arguments?"
#      89     )
#
# File pandas/_libs/lib.pyx:2922, in pandas._libs.lib.map_infer_mask()
#
# File pandas/_libs/lib.pyx:2959, in pandas._libs.lib._map_infer_mask()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\strings\object_array.py:376, in ObjectStringArrayMixin._str_split.<locals>.<lambda>(x)
#     374     if n is None or n == 0:
#     375         n = -1
# --> 376     f = lambda x: x.split(pat, n)
#     377 else:
#     378     new_pat: str | re.Pattern
#
# KeyboardInterrupt:

# %%
# Rewrite in humman language

import ast
game_reviews['tags'] = game_reviews['tags'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# Build FastText training lines
def to_fasttext_format(row):
    labels = " ".join([f"__label__{tag}" for tag in row['tags']])
    return f"{labels} {row['review_text']}"

game_reviews["fasttext_format"] = game_reviews.apply(to_fasttext_format, axis=1)

# Write to file for training
game_reviews["fasttext_format"].to_csv("fasttext_train.txt", index=False, header=False)

# %%
# Train FastText model
model = fasttext.train_supervised(
    input="fasttext_train.txt",
    lr=0.1,
    epoch=25,
    wordNgrams=2,
    dim=100,
    loss="ova"  # multi-label support
)

model.save_model("review_to_tag_model.ftz")

# %%
# game_reviews['embedding'] = game_reviews['review_text'].apply(model.get_sentence_vector)

# %%
import pandas as pd
from ast import literal_eval

# Ensure original tags are lists
tags_df['tags'] = tags_df['tags'].apply(lambda x: literal_eval(x) if isinstance(x, str) else x)
tags_df = tags_df.rename(columns={'APPID': 'app_id'})

# Predict tags per game
predictions = []
for _, row in game_reviews.iterrows():
    labels, probs = model.predict(row['review_text'], k=10)
    labels = [l.replace("__label__", "") for l in labels]
    predictions.append({
        'app_id': row['app_id'],
        'predicted_tags_with_probs': [f"{tag}:{p:.2f}" for tag, p in zip(labels, probs)]
    })

# Merge with original tags
merged_df = pd.DataFrame(predictions).merge(tags_df[['app_id', 'tags']], on='app_id')
display(merged_df)
# Out:
#       app_id                          predicted_tags_with_probs  \
# 0         10  [Multiplayer:0.91, Singleplayer:0.91, Classic:...
# 1         20  [Multiplayer:0.77, Singleplayer:0.74, Action:0...
# 2         30  [Multiplayer:0.85, Singleplayer:0.82, Action:0...
# 3         40  [Multiplayer:0.84, Singleplayer:0.78, Action:0...
# 4         50  [Singleplayer:0.84, Story:0.54, Adventure:0.52...
# ...      ...                                                ...
# 9827  563180  [Indie:0.52, Singleplayer:0.42, Casual:0.37, P...
# 9828  563400  [Indie:0.55, Casual:0.36, Adventure:0.34, Puzz...
# 9829  563430  [Singleplayer:0.51, Indie:0.50, Action:0.37, C...
# 9830  563510  [Indie:0.58, Casual:0.38, Action:0.35, Strateg...
# 9831  565340  [Indie:0.53, Action:0.33, Singleplayer:0.31, C...
#
#                                                    tags
# 0     [Action, FPS, Multiplayer, Shooter, Classic, F...
# 1     [Action, FPS, Multiplayer, Classic, Shooter, F...
# 2     [FPS, Multiplayer, Shooter, Action, Classic, F...
# 3     [Action, FPS, Classic, Multiplayer, Shooter, F...
# 4     [FPS, Action, Classic, Sci-fi, Singleplayer, S...
# ...                                                 ...
# 9827  [Indie, Adventure, Difficult, Platformer, Grea...
# 9828                   [Free to Play, Adventure, Indie]
# 9829  [RPG, Pixel Graphics, Sci-fi, Indie, Free to P...
# 9830                                       [Action, VR]
# 9831                                    [Action, Indie]
#
# [9832 rows x 3 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Prepare true and predicted labels
# true labels
y_true = merged_df['tags'].tolist()  # list of lists

# predicted labels
y_pred = merged_df['predicted_tags_with_probs'].apply(
    lambda tags_probs: [tp.split(':')[0] for tp in tags_probs]  # strip probabilities
).tolist()

# Binarize labels
mlb = MultiLabelBinarizer()
y_true_bin = mlb.fit_transform(y_true)
y_pred_bin = mlb.transform(y_pred)  # use the same classes as true

# Compute metrics
precision = precision_score(y_true_bin, y_pred_bin, average='micro')
recall = recall_score(y_true_bin, y_pred_bin, average='micro')
f1 = f1_score(y_true_bin, y_pred_bin, average='micro')

print(f"Precision (micro): {precision:.4f}")
print(f"Recall (micro): {recall:.4f}")
print(f"F1 score (micro): {f1:.4f}")
# Out:
# Accuracy (exact match): 0.0000
# Precision (micro): 0.4087
# Recall (micro): 0.5233
# F1 score (micro): 0.4589
# C:\Users\youdy\AppData\Roaming\Python\Python312\site-packages\sklearn\preprocessing\_label.py:909: UserWarning: unknown class(es) ['Early', 'Family', 'Female', 'Great', 'Open', 'Pixel', 'Point', 'Story', 'Third'] will be ignored
#   warnings.warn(

# %%
import requests

def get_tags(APPID:int):
    url = f"https://steamspy.com/api.php?request=appdetails&appid={APPID}"

    response = requests.get(url)

    if response.status_code == 200:
        return response.json()['tags']
    else:
        print(f"API fail for {APPID}")
